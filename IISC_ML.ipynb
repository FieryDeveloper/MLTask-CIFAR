# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img , img_to_array
from tensorflow.keras.layers import Dense , Dropout , Conv2D , MaxPooling2D, Flatten , BatchNormalization

from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
import seaborn as sns

# %%
(x_train , y_train) , (x_test , y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
print('Shape of x_train is {}'.format(x_train.shape))
print('Shape of x_test is {}'.format(x_test.shape))
print('Shape of y_train is {}'.format(y_train.shape))
print('Shape of y_test is {}'.format(y_test.shape))
# Out:
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (10000, 32, 32, 3)
# Shape of y_train is (50000, 1)
# Shape of y_test is (10000, 1)

# %%
plt.figure(figsize=(6,6))
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    img = x_train[i]
    plt.imshow(img)

# show the plot
plt.show()

# %%
def normalize(x):
    x = x.astype('float32')
    x = x/255.0
    return x

datagen = ImageDataGenerator(
                            rotation_range=15,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            horizontal_flip=True,
)

# %%
from sklearn.model_selection import train_test_split
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size = 0.5, random_state = 0)

# %%
x_train = normalize(x_train)
x_test = normalize(x_test)
x_val = normalize(x_val)

y_train = tf.keras.utils.to_categorical(y_train , 10)
y_test = tf.keras.utils.to_categorical(y_test , 10)
y_val  = tf.keras.utils.to_categorical(y_val , 10)

datagen.fit(x_train)

# %%
def results(model):
  epoch = 100

  epoch_range = range(1, epoch+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Classification Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Classification Accuracy")
  plt.show()

  # Plot training & validation loss values
  plt.plot(epoch_range,history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='lower right')
  plt.savefig("Model loss")
  plt.show()

# %%
weight_decay = 1e-4
model = Sequential([
                    Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(32, 32, 3)),
                    BatchNormalization(),
                    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.2),

                    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.3),

                    Conv2D(256, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    Conv2D(256, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
                    BatchNormalization(),
                    MaxPooling2D((2, 2)),
                    Dropout(0.4),

                    Flatten(),
                    Dense(256, activation='relu'),
                    BatchNormalization(),
                    Dropout(0.5),
                    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  batch_normalization (Batch  (None, 32, 32, 64)        256
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_1 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 256)               1048832
#
#  batch_normalization_6 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 2201418 (8.40 MB)
# Trainable params: 2199114 (8.39 MB)
# Non-trainable params: 2304 (9.00 KB)
# _________________________________________________________________

# %%
opt =    tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
callbacks = [ ReduceLROnPlateau(monitor='val_loss',
                                patience=10,
                                cooldown=1,
                                verbose=1),
              EarlyStopping(monitor='val_loss',
                            min_delta=1e-4,
                            patience=15)]

# %%
epoch = 200
history = model.fit(datagen.flow(x_train , y_train , batch_size = 64), epochs = epoch, steps_per_epoch=len(x_train)/64, validation_data = (x_val , y_val) , verbose = 1, callbacks=callbacks)
# Out:
# Epoch 1/200
# 781/781 [==============================] - 52s 48ms/step - loss: 1.7372 - accuracy: 0.4377 - val_loss: 1.3542 - val_accuracy: 0.5624 - lr: 0.0010
# Epoch 2/200
# 781/781 [==============================] - 34s 43ms/step - loss: 1.1664 - accuracy: 0.6181 - val_loss: 1.1144 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 3/200
# 781/781 [==============================] - 35s 44ms/step - loss: 1.0028 - accuracy: 0.6839 - val_loss: 0.8736 - val_accuracy: 0.7388 - lr: 0.0010
# Epoch 4/200
# 781/781 [==============================] - 35s 44ms/step - loss: 0
200
# 781/781 [==============================] - 34s 44ms/step - loss: 0.3299 - accuracy: 0.9446 - val_loss: 0.4382 - val_accuracy: 0.9190 - lr: 1.0000e-04
# Epoch 103/200
# 781/781 [==============================] - 34s 44ms/step - loss: 0.3318 - accuracy: 0.9423 - val_loss: 0.4415 - val_accuracy: 0.9156 - lr: 1.0000e-04
# Epoch 104/200
# 781/781 [==============================] - 33s 42ms/step - loss: 0.3280 - accuracy: 0.9430 - val_loss: 0.4564 - val_accuracy: 0.9118 - lr: 1.0000e-04
# Epoch 105/200
# 781/781 [==============================] - 36s 46ms/step - loss: 0.3268 - accuracy: 0.9431 - val_loss: 0.4390 - val_accuracy: 0.9196 - lr: 1.0000e-04
# Epoch 106/200
# 782/781 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.9447
# Epoch 106: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 781/781 [==============================] - 35s 44ms/step - loss: 0.3221 - accuracy: 0.9447 - val_loss: 0.4426 - val_accuracy: 0.9156 - lr: 1.0000e-04
# Epoch 107/200
# 781/781 [==============================] - 35s 44ms/step - loss: 0.3169 - accuracy: 0.9457 - val_loss: 0.4393 - val_accuracy: 0.9154 - lr: 1.0000e-05
# Epoch 108/200
# 781/781 [==============================] - 34s 43ms/step - loss: 0.3136 - accuracy: 0.9470 - val_loss: 0.4412 - val_accuracy: 0.9160 - lr: 1.0000e-05
# Epoch 109/200
# 781/781 [==============================] - 35s 44ms/step - loss: 0.3102 - accuracy: 0.9480 - val_loss: 0.4372 - val_accuracy: 0.9164 - lr: 1.0000e-05
# Epoch 110/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.3112 - accuracy: 0.9479 - val_loss: 0.4363 - val_accuracy: 0.9174 - lr: 1.0000e-05
# Epoch 111/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.3058 - accuracy: 0.9505 - val_loss: 0.4331 - val_accuracy: 0.9182 - lr: 1.0000e-05
# Epoch 112/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.3058 - accuracy: 0.9496 - val_loss: 0.4389 - val_accuracy: 0.9166 - lr: 1.0000e-05
# Epoch 113/200
# 781/781 [==============================] - 36s 46ms/step - loss: 0.3053 - accuracy: 0.9498 - val_loss: 0.4340 - val_accuracy: 0.9188 - lr: 1.0000e-05
# Epoch 114/200
# 781/781 [==============================] - 34s 44ms/step - loss: 0.3035 - accuracy: 0.9505 - val_loss: 0.4332 - val_accuracy: 0.9182 - lr: 1.0000e-05
# Epoch 115/200
# 781/781 [==============================] - 36s 45ms/step - loss: 0.3059 - accuracy: 0.9497 - val_loss: 0.4324 - val_accuracy: 0.9194 - lr: 1.0000e-05
# Epoch 116/200
# 781/781 [==============================] - 36s 46ms/step - loss: 0.3045 - accuracy: 0.9498 - val_loss: 0.4315 - val_accuracy: 0.9190 - lr: 1.0000e-05
# Epoch 117/200
# 781/781 [==============================] - 36s 45ms/step - loss: 0.3013 - accuracy: 0.9515 - val_loss: 0.4308 - val_accuracy: 0.9192 - lr: 1.0000e-05
# Epoch 118/200
# 781/781 [==============================] - 36s 45ms/step - loss: 0.3030 - accuracy: 0.9513 - val_loss: 0.4321 - val_accuracy: 0.9192 - lr: 1.0000e-05
# Epoch 119/200
# 781/781 [==============================] - 36s 46ms/step - loss: 0.3029 - accuracy: 0.9503 - val_loss: 0.4319 - val_accuracy: 0.9190 - lr: 1.0000e-05
# Epoch 120/200
# 781/781 [==============================] - 37s 47ms/step - loss: 0.2984 - accuracy: 0.9519 - val_loss: 0.4298 - val_accuracy: 0.9196 - lr: 1.0000e-05
# Epoch 121/200
# 781/781 [==============================] - 36s 46ms/step - loss: 0.3023 - accuracy: 0.9501 - val_loss: 0.4316 - val_accuracy: 0.9190 - lr: 1.0000e-05
# Epoch 122/200
# 781/781 [==============================] - 36s 45ms/step - loss: 0.3027 - accuracy: 0.9507 - val_loss: 0.4295 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 123/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.3032 - accuracy: 0.9499 - val_loss: 0.4302 - val_accuracy: 0.9196 - lr: 1.0000e-05
# Epoch 124/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.3006 - accuracy: 0.9507 - val_loss: 0.4292 - val_accuracy: 0.9194 - lr: 1.0000e-05
# Epoch 125/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.3000 - accuracy: 0.9504 - val_loss: 0.4332 - val_accuracy: 0.9192 - lr: 1.0000e-05
# Epoch 126/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2983 - accuracy: 0.9512 - val_loss: 0.4289 - val_accuracy: 0.9194 - lr: 1.0000e-05
# Epoch 127/200
# 781/781 [==============================] - 35s 44ms/step - loss: 0.2947 - accuracy: 0.9522 - val_loss: 0.4318 - val_accuracy: 0.9190 - lr: 1.0000e-05
# Epoch 128/200
# 781/781 [==============================] - 36s 45ms/step - loss: 0.2986 - accuracy: 0.9514 - val_loss: 0.4304 - val_accuracy: 0.9196 - lr: 1.0000e-05
# Epoch 129/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2980 - accuracy: 0.9503 - val_loss: 0.4303 - val_accuracy: 0.9192 - lr: 1.0000e-05
# Epoch 130/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2963 - accuracy: 0.9525 - val_loss: 0.4289 - val_accuracy: 0.9190 - lr: 1.0000e-05
# Epoch 131/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2991 - accuracy: 0.9505 - val_loss: 0.4287 - val_accuracy: 0.9192 - lr: 1.0000e-05
# Epoch 132/200
# 781/781 [==============================] - 35s 44ms/step - loss: 0.2928 - accuracy: 0.9530 - val_loss: 0.4249 - val_accuracy: 0.9184 - lr: 1.0000e-05
# Epoch 133/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2956 - accuracy: 0.9514 - val_loss: 0.4227 - val_accuracy: 0.9178 - lr: 1.0000e-05
# Epoch 134/200
# 781/781 [==============================] - 36s 45ms/step - loss: 0.2920 - accuracy: 0.9522 - val_loss: 0.4258 - val_accuracy: 0.9192 - lr: 1.0000e-05
# Epoch 135/200
# 781/781 [==============================] - 36s 47ms/step - loss: 0.2934 - accuracy: 0.9529 - val_loss: 0.4265 - val_accuracy: 0.9194 - lr: 1.0000e-05
# Epoch 136/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2940 - accuracy: 0.9512 - val_loss: 0.4285 - val_accuracy: 0.9188 - lr: 1.0000e-05
# Epoch 137/200
# 781/781 [==============================] - 35s 44ms/step - loss: 0.2967 - accuracy: 0.9505 - val_loss: 0.4283 - val_accuracy: 0.9186 - lr: 1.0000e-05
# Epoch 138/200
# 781/781 [==============================] - 36s 45ms/step - loss: 0.2897 - accuracy: 0.9532 - val_loss: 0.4293 - val_accuracy: 0.9178 - lr: 1.0000e-05
# Epoch 139/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2905 - accuracy: 0.9533 - val_loss: 0.4277 - val_accuracy: 0.9186 - lr: 1.0000e-05
# Epoch 140/200
# 781/781 [==============================] - 34s 44ms/step - loss: 0.2915 - accuracy: 0.9535 - val_loss: 0.4284 - val_accuracy: 0.9202 - lr: 1.0000e-05
# Epoch 141/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2887 - accuracy: 0.9543 - val_loss: 0.4287 - val_accuracy: 0.9188 - lr: 1.0000e-05
# Epoch 142/200
# 781/781 [==============================] - 36s 46ms/step - loss: 0.2875 - accuracy: 0.9531 - val_loss: 0.4301 - val_accuracy: 0.9180 - lr: 1.0000e-05
# Epoch 143/200
# 781/781 [============================>.] - ETA: 0s - loss: 0.2895 - accuracy: 0.9533
# Epoch 143: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2894 - accuracy: 0.9533 - val_loss: 0.4277 - val_accuracy: 0.9198 - lr: 1.0000e-05
# Epoch 144/200
# 781/781 [==============================] - 34s 44ms/step - loss: 0.2895 - accuracy: 0.9533 - val_loss: 0.4287 - val_accuracy: 0.9194 - lr: 1.0000e-06
# Epoch 145/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2885 - accuracy: 0.9543 - val_loss: 0.4294 - val_accuracy: 0.9194 - lr: 1.0000e-06
# Epoch 146/200
# 781/781 [==============================] - 35s 44ms/step - loss: 0.2900 - accuracy: 0.9543 - val_loss: 0.4267 - val_accuracy: 0.9202 - lr: 1.0000e-06
# Epoch 147/200
# 781/781 [==============================] - 36s 46ms/step - loss: 0.2886 - accuracy: 0.9533 - val_loss: 0.4278 - val_accuracy: 0.9202 - lr: 1.0000e-06
# Epoch 148/200
# 781/781 [==============================] - 35s 45ms/step - loss: 0.2876 - accuracy: 0.9537 - val_loss: 0.4283 - val_accuracy: 0.9196 - lr: 1.0000e-06

# %%
acc = model.evaluate(x_test , y_test)
print("test set loss : " , acc[0])
print("test set accuracy :", acc[1]*100)
# Out:
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4105 - accuracy: 0.9206
# test set loss :  0.41052278876304626
# test set accuracy : 92.05999970436096

# %%
model.save("cnn.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
